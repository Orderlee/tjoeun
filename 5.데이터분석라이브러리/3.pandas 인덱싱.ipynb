# %%
import pandas as pd
#딕셔너리 자료형
data={'names':['김철수','이철호','김영희','박민수','송철호'],
     'year':[2014,2015,2016,2017,2018],
     'points':[150,170,360,240,290]}
df= pd.DataFrame(data) #표 형식의 데이터
df
# Out:
#   names  year  points
# 0   김철수  2014     150
# 1   이철호  2015     170
# 2   김영희  2016     360
# 3   박민수  2017     240
# 4   송철호  2018     290

# %%
print(df['year']) # year 필드 선택
print(df.year)
# Out:
# 0    2014
# 1    2015
# 2    2016
# 3    2017
# 4    2018
# Name: year, dtype: int64
# 0    2014
# 1    2015
# 2    2016
# 3    2017
# 4    2018
# Name: year, dtype: int64

# %%
df[['year','points']]
# Out:
#    year  points
# 0  2014     150
# 1  2015     170
# 2  2016     360
# 3  2017     240
# 4  2018     290

# %%
df=pd.read_csv('d:/data/traffic/data.csv',encoding='ms949')
df
#인코딩 형식이 맞지 않을 때 발생하는 에러
#unicodedecodeErroer: 'utf-8' code can't decode byte
#0xbc in position 2: invalid start byte
# Out:
#      호선   역번호  역      명         계    일평균       1월       2월       3월       4월  \
# 0     1   150    서울역(1)  19799600  93562  2823972  2542481  2885932  2918104
# 1     1   151     시청(1)   9478426  44701  1367861  1114504  1380702  1432476
# 2     1   152        종각  16783116  78856  2529090  2098588  2445715  2433679
# 3     1   153   종로3가(1)  11553939  54481  1729440  1465221  1692299  1638929
# 4     1   154      종로5가  10379864  49299  1532069  1303823  1558679  1532793
# ..   ..   ...       ...       ...    ...      ...      ...      ...      ...
# 283   9  4134      송파나루   1324501   6146   172531   154426   189654   200834
# 284   9  4135      한성백제    691398   3229    89927    77050    95084   100688
# 285   9  4136  올림픽공원(9)   2674546  12209   306660   255489   367268   378991
# 286   9  4137      둔촌오륜    307202   1429    36489    33254    46402    47914
# 287   9  4138    중앙보훈병원   2473023  11423   322250   281153   344386   369543
#
#           5월       6월       7월
# ...

# %%
df=pd.read_csv('d:/data/traffic/data.csv',engine='python')
df
# Out:
#      호선   역번호  역      명         계    일평균       1월       2월       3월       4월  \
# 0     1   150    서울역(1)  19799600  93562  2823972  2542481  2885932  2918104
# 1     1   151     시청(1)   9478426  44701  1367861  1114504  1380702  1432476
# 2     1   152        종각  16783116  78856  2529090  2098588  2445715  2433679
# 3     1   153   종로3가(1)  11553939  54481  1729440  1465221  1692299  1638929
# 4     1   154      종로5가  10379864  49299  1532069  1303823  1558679  1532793
# ..   ..   ...       ...       ...    ...      ...      ...      ...      ...
# 283   9  4134      송파나루   1324501   6146   172531   154426   189654   200834
# 284   9  4135      한성백제    691398   3229    89927    77050    95084   100688
# 285   9  4136  올림픽공원(9)   2674546  12209   306660   255489   367268   378991
# 286   9  4137      둔촌오륜    307202   1429    36489    33254    46402    47914
# 287   9  4138    중앙보훈병원   2473023  11423   322250   281153   344386   369543
#
#           5월       6월       7월
# ...

# %%
del df['역번호'] #필드삭제
print(df.head())
# Out:
#    호선 역      명         계    일평균       1월       2월       3월       4월       5월  \
# 0   1   서울역(1)  19799600  93562  2823972  2542481  2885932  2918104  2993718
# 1   1    시청(1)   9478426  44701  1367861  1114504  1380702  1432476  1460584
# 2   1       종각  16783116  78856  2529090  2098588  2445715  2433679  2496189
# 3   1  종로3가(1)  11553939  54481  1729440  1465221  1692299  1638929  1734230
# 4   1     종로5가  10379864  49299  1532069  1303823  1558679  1532793  1571939
#
#         6월       7월
# 0  2770656  2864737
# 1  1334755  1387544
# 2  2269648  2510207
# 3  1600924  1692896
# 4  1423812  1456749

# %%
df2=df.drop(0) #0번행 삭제
df2.head()
# Out:
#    호선 역      명         계    일평균       1월       2월       3월       4월       5월  \
# 1   1    시청(1)   9478426  44701  1367861  1114504  1380702  1432476  1460584
# 2   1       종각  16783116  78856  2529090  2098588  2445715  2433679  2496189
# 3   1  종로3가(1)  11553939  54481  1729440  1465221  1692299  1638929  1734230
# 4   1     종로5가  10379864  49299  1532069  1303823  1558679  1532793  1571939
# 5   1   동대문(1)   5418592  25741   743915   682919   820750   799545   837528
#
#         6월       7월
# 1  1334755  1387544
# 2  2269648  2510207
# 3  1600924  1692896
# 4  1423812  1456749
# 5   774367   759568

# %%
df2=df.drop(['7월'],axis=1) #필드 삭제
df2.head()
# Out:
#    호선 역      명         계    일평균       1월       2월       3월       4월       5월  \
# 0   1   서울역(1)  19799600  93562  2823972  2542481  2885932  2918104  2993718
# 1   1    시청(1)   9478426  44701  1367861  1114504  1380702  1432476  1460584
# 2   1       종각  16783116  78856  2529090  2098588  2445715  2433679  2496189
# 3   1  종로3가(1)  11553939  54481  1729440  1465221  1692299  1638929  1734230
# 4   1     종로5가  10379864  49299  1532069  1303823  1558679  1532793  1571939
#
#         6월
# 0  2770656
# 1  1334755
# 2  2269648
# 3  1600924
# 4  1423812

# %%
df2=df.drop(['5월','6월'],axis=1) # 2개 이상의 필드 삭제
df2
# Out:
#      호선  역      명         계    일평균       1월       2월       3월       4월  \
# 0     1    서울역(1)  19799600  93562  2823972  2542481  2885932  2918104
# 1     1     시청(1)   9478426  44701  1367861  1114504  1380702  1432476
# 2     1        종각  16783116  78856  2529090  2098588  2445715  2433679
# 3     1   종로3가(1)  11553939  54481  1729440  1465221  1692299  1638929
# 4     1      종로5가  10379864  49299  1532069  1303823  1558679  1532793
# ..   ..       ...       ...    ...      ...      ...      ...      ...
# 283   9      송파나루   1324501   6146   172531   154426   189654   200834
# 284   9      한성백제    691398   3229    89927    77050    95084   100688
# 285   9  올림픽공원(9)   2674546  12209   306660   255489   367268   378991
# 286   9      둔촌오륜    307202   1429    36489    33254    46402    47914
# 287   9    중앙보훈병원   2473023  11423   322250   281153   344386   369543
#
#           7월
# 0    2864737
# 1    1387544
# 2    2510207
# 3    1692896
# 4    1456749
# ..       ...
# ...

# %%
print(df.loc[0])
print(df.loc[1])
# Out:
# 호선                 1
# 역      명      서울역(1)
# 계           19799600
# 일평균            93562
# 1월           2823972
# 2월           2542481
# 3월           2885932
# 4월           2918104
# 5월           2993718
# 6월           2770656
# 7월           2864737
# Name: 0, dtype: object
# 호선                1
# 역      명      시청(1)
# 계           9478426
# 일평균           44701
# 1월          1367861
# 2월          1114504
# 3월          1380702
# 4월          1432476
# 5월          1460584
# 6월          1334755
# 7월          1387544
# Name: 1, dtype: object

# %%
#loc() key기반 탐색
#iloc() index 기반 탐색

# %%
df[0:3] #0~2
# Out:
#    호선 역      명         계    일평균       1월       2월       3월       4월       5월  \
# 0   1   서울역(1)  19799600  93562  2823972  2542481  2885932  2918104  2993718
# 1   1    시청(1)   9478426  44701  1367861  1114504  1380702  1432476  1460584
# 2   1       종각  16783116  78856  2529090  2098588  2445715  2433679  2496189
#
#         6월       7월
# 0  2770656  2864737
# 1  1334755  1387544
# 2  2269648  2510207

# %%
df2=df[0:3]
df2.index=['a','b','c']
df2
# Out:
#    호선 역      명         계    일평균       1월       2월       3월       4월       5월  \
# a   1   서울역(1)  19799600  93562  2823972  2542481  2885932  2918104  2993718
# b   1    시청(1)   9478426  44701  1367861  1114504  1380702  1432476  1460584
# c   1       종각  16783116  78856  2529090  2098588  2445715  2433679  2496189
#
#         6월       7월
# a  2770656  2864737
# b  1334755  1387544
# c  2269648  2510207

# %%
df.loc[0:3,'일평균'] # loc[행범위.열범위] ->이름으로 찾아서 3까지 나옴
# Out:
# 0    93562
# 1    44701
# 2    78856
# 3    54481
# Name: 일평균, dtype: int64

# %%
df.head().loc[: , ['계','일평균']] # : 전체행
# Out:
#           계    일평균
# 0  19799600  93562
# 1   9478426  44701
# 2  16783116  78856
# 3  11553939  54481
# 4  10379864  49299

# %%
df.iloc[1,1] #1행 1열 필드값 1개
# Out:
# '시청(1)'

# %%
df.iloc[3] #3행
# Out:
# 호선                 1
# 역      명     종로3가(1)
# 계           11553939
# 일평균            54481
# 1월           1729440
# 2월           1465221
# 3월           1692299
# 4월           1638929
# 5월           1734230
# 6월           1600924
# 7월           1692896
# Name: 3, dtype: object

# %%
df.iloc[3:5,0:2] #3,4행 0,1열
# Out:
#    호선 역      명
# 3   1  종로3가(1)
# 4   1     종로5가

# %%
df.iloc[[0,1,3],[1,2]] #0,1,3행 1,2열
# Out:
#   역      명         계
# 0   서울역(1)  19799600
# 1    시청(1)   9478426
# 3  종로3가(1)  11553939

# %%
df.head().iloc[:,1:4] #모든행, 1~3열
# Out:
#   역      명         계    일평균
# 0   서울역(1)  19799600  93562
# 1    시청(1)   9478426  44701
# 2       종각  16783116  78856
# 3  종로3가(1)  11553939  54481
# 4     종로5가  10379864  49299

# %%
df['일평균']
# Out:
# 0      93562
# 1      44701
# 2      78856
# 3      54481
# 4      49299
#        ...
# 283     6146
# 284     3229
# 285    12209
# 286     1429
# 287    11423
# Name: 일평균, Length: 288, dtype: int64

# %%
#boolean 인덱싱
df['일평균'] >50000
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 283    False
# 284    False
# 285    False
# 286    False
# 287    False
# Name: 일평균, Length: 288, dtype: bool

# %%
# loc[행범위, 열범위]
df.loc[df['일평균']>50000, : ]
# Out:
#      호선    역      명         계     일평균       1월       2월       3월       4월  \
# 0     1      서울역(1)  19799600   93562  2823972  2542481  2885932  2918104
# 2     1          종각  16783116   78856  2529090  2098588  2445715  2433679
# 3     1     종로3가(1)  11553939   54481  1729440  1465221  1692299  1638929
# 11    2       을지로입구  15747392   73925  2295751  1911486  2302489  2323887
# 21    2     건대입구(2)  12999984   61609  1827382  1622225  1966176  1887245
# 23    2          강변  13221960   62639  1872966  1744053  1947833  1898358
# 25    2       잠실(2)  24999222  118023  3559239  3215966  3525021  3880333
# 28    2          삼성  18235230   84724  2654408  2169127  2595130  2656266
# 29    2          선릉  15815754   73897  2393573  1888801  2257543  2341619
# 30    2          역삼  15332683   71571  2363722  1862707  2210273  2262573
# 31    2          강남  30502880  142123  4749571  3901121  4367422  4234069
# 32    2       교대(2)  10797166   50654  1573477  1278127  1591561  1614441
# ...
