# %%
import pandas as pd
df=pd.read_csv('d:/data/energy/ENB2012_2data.csv')
df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2  class
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33      0
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33      0
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33      0
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33      0
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28      0

# %%
df['class'].value_counts()
# Out:
# 0    400
# 1    368
# Name: class, dtype: int64

# %%
train_cols=df.columns[0:8]
X=df[train_cols] # 독립변수
y=df['class'] #종속변수

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import mglearn
pd.plotting.scatter_matrix(X,c=y,figsize=(15,15),marker='o',
                          cmap=mglearn.cm3)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\externals\six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# C:\Anaconda\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CF7EC288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CF17C448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFAC0FC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFB00148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFB391C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFB702C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFBA8408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFBDF508>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFBEC108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFC271C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFC896C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFCC17C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFCF9908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFD31A08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFD6AAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFDA3C08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFDDCD08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFE13E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFE4AF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFE850C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFEBF108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFEF8208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFF30348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFF68448>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFFA0548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8CFFDEE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D000F748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D0048848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D0082988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D00BAA88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D00F1B08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D0129C48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D0161D48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D0198E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D01D1F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D020D0C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D0246148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D027F288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D02B6388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D02EE488>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D0325608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D0365E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D0397748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D03D2888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D0407988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D0440A88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D0477B48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D04AEC88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D04E8D88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D0520E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D0556FC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D0594088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D05CD188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D06062C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D063C3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D06744C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D06AC588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D06EBE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D071E788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D07558C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D078D9C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D07C5A88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D07FEC08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D0837D08>]],
#       dtype=object)

# %%
#언더샘플링
from imblearn.under_sampling import RandomUnderSampler
X_sample,y_sample=RandomUnderSampler(random_state=0).fit_sample(X,y)
X_samp=pd.DataFrame(data=X_sample,columns=train_cols)
y_samp=pd.DataFrame(data=y_sample,columns=['class'])
df2=pd.concat([X_samp,y_samp],axis=1)
# Out:
# Using TensorFlow backend.

# %%
df2['class'].value_counts() #샘플링 후의 0,1 카운트
# Out:
# 1    368
# 0    368
# Name: class, dtype: int64

# %%
#샘플링 데이터셋에서 독립변수,종속변수 구분
X=X_samp[train_cols]
y=y_samp['class']

# %%
#학습용:검증용 8:2구분
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,
                                                stratify=y,random_state=0)

# %%
n1=0
n2=0
for i in y_test.values:
    if i ==0:
        n1+=1
    else:
        n2+=1
print(n1,n2)
# Out:
# 74 74

# %%
#인공신경망 모형
from sklearn.neural_network import MLPClassifier
model=MLPClassifier(random_state=100,max_iter=500)
model.fit(X_train,y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=500,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=100, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
#예측정확도
print(model.score(X_train,y_train))
print(model.score(X_test,y_test))
# Out:
# 0.9846938775510204
# 0.972972972972973

# %%
from sklearn.metrics import confusion_matrix
pred=model.predict(X_test)
cm=confusion_matrix(y_test,pred)
df_cm=pd.DataFrame(cm,index=['0','1'],columns=['0','1'])
df_cm
# Out:
#     0   1
# 0  70   4
# 1   0  74

# %%
import pandas as pd
df=pd.read_csv('d:/data/energy/ENB2012_2data.csv')
df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2  class  class2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33      0       0
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33      0       0
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33      0       0
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33      0       0
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28      0       1

# %%
df['class2'].value_counts()
# Out:
# 0    393
# 1    375
# Name: class2, dtype: int64

# %%
train_cols=df.columns[0:8]
X=df[train_cols] # 독립변수
y=df['class2'] #종속변수

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import mglearn
pd.plotting.scatter_matrix(X,c=y,figsize=(15,15),marker='o',
                          cmap=mglearn.cm3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D554F348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D897C3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D89B2E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D89EAF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8A260C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8A5E1C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8A97288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8AD0388>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8AD7F48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8B14148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8B786C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8BB1748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8BEA848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8C23988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8C5CA88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8C93B88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8CCCC48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8D06D88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8D3EE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8D76F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8DB5108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8DEF208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8E26288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8E5F3C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8E984C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8ED15C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8F08708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8F41788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8F7A888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8FB29C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D8FEDAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D9025BC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D905DD08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D9096E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D90D0F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D910D088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8D9144188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA14C248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA186348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA1BD488>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA1F7588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA236E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA268748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA2A2848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA2DB948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA314A88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA34BB88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA384C48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA3BDD88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA3F5E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA42CF88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA469108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA4A6208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA4DD288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA5153C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA54F4C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA5885C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA5BF6C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA5F87C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA6328C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA66A9C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA6A4B08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA6DCC08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8DA715CC8>]],
#       dtype=object)

# %%
#언더샘플링
from imblearn.under_sampling import RandomUnderSampler
X_sample,y_sample=RandomUnderSampler(random_state=0).fit_sample(X,y)
X_samp=pd.DataFrame(data=X_sample,columns=train_cols)
y_samp=pd.DataFrame(data=y_sample,columns=['class2'])
df2=pd.concat([X_samp,y_samp],axis=1)

# %%
df2['class2'].value_counts() #샘플링 후의 0,1 카운트
# Out:
# 1    375
# 0    375
# Name: class2, dtype: int64

# %%
#샘플링 데이터셋에서 독립변수,종속변수 구분
X=X_samp[train_cols]
y=y_samp['class2']

# %%
#학습용:검증용 8:2구분
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,
                                                stratify=y,random_state=0)

# %%
#인공신경망 모형
from sklearn.neural_network import MLPClassifier
model=MLPClassifier(random_state=100,max_iter=500)
model.fit(X_train,y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=500,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=100, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
#예측정확도
print(model.score(X_train,y_train))
print(model.score(X_test,y_test))
# Out:
# 0.9883333333333333
# 0.9866666666666667

# %%
from sklearn.metrics import confusion_matrix
pred=model.predict(X_test)
cm=confusion_matrix(y_test,pred)
df_cm=pd.DataFrame(cm,index=['0','1'],columns=['0','1'])
df_cm
# Out:
#     0   1
# 0  73   2
# 1   0  75
